# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df_cost=pd.read_csv(r"C:\Users\ABHISHEK MITTAL\Icertis\DataSets\Cost.csv")
df_cost.head()
# Out:
#     Crop           State  Cost of Cultivation (`/Hectare) A2+FL  \
# 0  ARHAR   Uttar Pradesh                                9794.05
# 1  ARHAR       Karnataka                               10593.15
# 2  ARHAR         Gujarat                               13468.82
# 3  ARHAR  Andhra Pradesh                               17051.66
# 4  ARHAR     Maharashtra                               17130.55
#
#    Cost of Cultivation (`/Hectare) C2  Cost of Production (`/Quintal) C2  \
# 0                            23076.74                            1941.55
# 1                            16528.68                            2172.46
# 2                            19551.90                            1898.30
# 3                            24171.65                            3670.54
# 4                            25270.26                            2775.80
#
#    Yield (Quintal/ Hectare)
# 0                       9.83
# 1                       7.47
# 2                       9.59
# ...

# %%
df_cost.shape
# Out:
# (49, 6)

# %%
df_cost.columns.isnull()
# Out:
# array([False, False, False, False, False, False])

# %%
plt.figure(figsize=(16, 6))
sns.barplot(x=df_cost['Crop'],y=df_cost['Yield (Quintal/ Hectare) '])

# %%
plt.figure(figsize=(16, 6))
sns.scatterplot(y=df_cost['Crop'],x=df_cost['State'])

# %%
df_produce=pd.read_csv(r"C:\Users\ABHISHEK MITTAL\Icertis\DataSets\Production-Yearly.csv")

# %%
df_produce.shape
# Out:
# (55, 16)

# %%
df_produce.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False])

# %%
df_produce.head()
# Out:
#   Crop               Production 2006-07  Production 2007-08  \
# 0  Total Foodgrains               158.8               168.6
# 1              Rice               200.8               207.9
# 2             Wheat               131.6               136.4
# 3             Jowar               124.3               137.8
# 4             Bajra               136.4               161.5
#
#    Production 2008-09  Production 2009-10  Production 2010-11  Area 2006-07  \
# 0               171.3               159.4               178.9         128.5
# 1               213.3               191.6               206.4         168.5
# 2               140.1               140.3               150.8         115.0
# 3               126.0               116.5               121.8         120.7
# 4               143.9               105.4               167.9          94.5
#
#    Area 2007-08  Area 2008-09  Area 2009-10  Area 2010-11  Yield 2006-07  \
# ...

# %%
df_produce
# Out:
#             Crop               Production 2006-07  Production 2007-08  \
# 0            Total Foodgrains               158.8               168.6
# 1                        Rice               200.8               207.9
# 2                       Wheat               131.6               136.4
# 3                       Jowar               124.3               137.8
# 4                       Bajra               136.4               161.5
# 5                       Maize               198.8               249.6
# 6                        Ragi                56.1                83.6
# 7               Small millets                53.9                61.9
# 8                      Barley                88.1                79.3
# 9              Coarse Cereals               138.5               166.4
# 10                    Cereals               164.1               174.6
# 11                       Gram               140.6               127.6
# ...
